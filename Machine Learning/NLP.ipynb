# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
sw=stopwords.words('english')
sw
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
# ...

# %%
sent='there will be no redemption'
nltk.download('punkt_tab')
tokens=nltk.word_tokenize(sent)
tokens
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ['there', 'will', 'be', 'no', 'redemption']

# %%
l1=['apple','mango','orange']
l2=['apple','mango','grapes','pineapple']
new=[i for i in l2 if i not in l1]
new
# Out:
# ['grapes', 'pineapple']

# %%
filtered_tokens=[i for i in tokens if i not in sw]
filtered_tokens
# Out:
# ['redemption']

# %%
from nltk.util import ngrams
ngram=ngrams(sequence=nltk.word_tokenize(sent),n=2)
for i in ngram:
  print(i)
# Out:
# ('there', 'will')
# ('will', 'be')
# ('be', 'no')
# ('no', 'redemption')

# %%
words=['programs','watching','sleeping','completes','caught','completed']
from nltk.stem import PorterStemmer
ps=PorterStemmer()
for w in words:
  print(w,':',ps.stem(w))
# Out:
# programs : program
# watching : watch
# sleeping : sleep
# completes : complet
# caught : caught
# completed : complet

# %%
from nltk.stem import SnowballStemmer
ss=SnowballStemmer('english')
for w in words:
  print(w,':',ss.stem(w))
# Out:
# programs : program
# watching : watch
# sleeping : sleep
# completes : complet
# caught : caught
# completed : complet

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
wnl=WordNetLemmatizer()
for i in words:
  print(i,':',wnl.lemmatize(i,pos='v'))
# Out:
# programs : program
# watching : watch
# sleeping : sleep
# completes : complete
# caught : catch
# completed : complete
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
