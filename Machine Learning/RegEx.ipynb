# %%
s='***$ Good morning !!!!'
w=''
for i in s:
  if i.isalpha():
    w+=i
  elif i==' ':
    w+=i
w
# Out:
# ' Good morning '

# %%
import re
s='python 6.8 programming is 9 simple!!!!!1'
result=re.sub(r'\d','',s)
result=re.sub(r'[^\w ]','',result)
result
# Out:
# 'python  programming is  simple'

# %%
result=re.sub(r'[^A-z ]','',s)
result
# Out:
# 'python  programming is  simple'
